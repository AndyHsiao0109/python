# %% [markdown]
# #Tuple (元組)<br>
# tuple(元組)可視為不可改變的串列，tuple跟list很像，但是我們不能新增、刪除或更新tuple的元素。tuple的好處有：<br>
#
# 1.佔用較少空間<br>
# 2.可當作dictionary(字典)的鍵值<br>
# 3.可當作函式引數<br>

# %%
a_tuple=('python', 'js', 'SQL') 
print(a_tuple) #針對字典 印出字典的key組成的tuple
b_list=['go', 'c#', 'vb']
b_tuple=tuple(b_list) #b_tuple=b_list的原組
print(b_tuple)
print(b_tuple[0])
# Out:
# ('python', 'js', 'SQL')
# ('go', 'c#', 'vb')
# go

# %% [markdown]
# #字典(dictionary - dict)為帶有鍵值(key)的串列(list)

# %%
languages = {}
languages = {'name':'python', 'version':'3.7'} #索引值(鍵值)可以自訂
print(languages['name']) #印出languages的name的內容
print(languages['version']) #印出languages的version的內容
a={0:'python', 1:'java', 2:'SQL'}
print(a[0]) #印出a的第0個的內容
print(a[1])
print(a[2])
print(languages)
print(languages.keys())
print(languages.values())
print(languages.items())
print('name' in languages) #列印name是否在languages內
# Out:
# python
# 3.7
# python
# java
# SQL
# {'name': 'python', 'version': '3.7'}
# dict_keys(['name', 'version'])
# dict_values(['python', '3.7'])
# dict_items([('name', 'python'), ('version', '3.7')])
# True
